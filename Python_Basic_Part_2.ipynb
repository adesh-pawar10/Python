# %%
import datetime

# %%
datetime.date.today()
# Out:
# datetime.date(2022, 10, 11)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 10, 11, 9, 36, 18, 697964)

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 10, 11, 9, 37, 3, 651787)

# %%
date.today()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 date.today()
#
# NameError: name 'date' is not defined

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2022, 10, 11)

# %%
birthday_day = date(2001, 11, 4)
birthday_day
# Out:
# datetime.date(2001, 11, 4)

# %%
print(date.today() - birthday_day)
# Out:
# 7646 days, 0:00:00

# %%
hund_day = date.today() + 100
hund_day
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 hund_day = date.today() + 100
#       2 hund_day
#
# TypeError: unsupported operand type(s) for +: 'datetime.date' and 'int'

# %%
from datetime import *

# %%
hund_day = date.today() + timedelta(days=100)
hund_day
# Out:
# datetime.date(2023, 1, 19)

# %% [markdown]
# # Math Operators

# %%
print(10+4)
# Out:
# 14

# %%
print(10-6)
# Out:
# 4

# %%
print(10*4)
# Out:
# 40

# %%
print(10**4)
# Out:
# 10000

# %%
print(10/4)
# Out:
# 2.5

# %%
print(10%4)
# Out:
# 2
