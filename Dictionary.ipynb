# %% [markdown]
# ## collections in python
# ## Dictionary

# %% [markdown]
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.

# %%
#dictionary

d1 =  dict()
print(d1 , type(d1))
# Out:
# {} <class 'dict'>

# %%
d2 = {1: "Arav" , 2: "Kiara" , 3: "Nyra" , 4: "Hrutvik", 5: "Vicky"}
#key --- value pair ---> unique
print(d2)
# Out:
# {1: 'Arav', 2: 'Kiara', 3: 'Nyra', 4: 'Hrutvik', 5: 'Vicky'}

# %% [markdown]
# #### Dictionary Items
#
#     Dictionary items are ordered, changeable, and does not allow duplicates.
#
#     Dictionary items are presented in key:value pairs, and can be referred to by using the key name.

# %%
# Example

print(d2[1])
# Out:
# Arav

# %% [markdown]
# ##### When we say that dictionaries are ordered, it means that the items have a defined order, and that order will not change.
#
# ##### Unordered means that the items does not have a defined order, you cannot refer to an item by using an index.

# %% [markdown]
# ## Changeable
# Dictionaries are changeable, meaning that we can change, add or remove items after the dictionary has been created.

# %%
# Duplicates Not Allowed
# Dictionaries cannot have two items with the same key:

# Example
# Duplicate values will overwrite existing values:

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
# Dictionary Items - Data Types
# The values in dictionary items can be of any data type:

# Example
# String, int, boolean, and list data types:

thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %%
thisdict
# Out:
# {'brand': 'Ford',
#  'electric': False,
#  'year': 1964,
#  'colors': ['red', 'white', 'blue']}

# %%
print(type(thisdict))
# Out:
# <class 'dict'>

# %% [markdown]
# ## Dictionary Manipulation Function

# %%
d1 = {1:'Pune', 2:'Mumbai', 3:'Delhi', 4:'Bangalore', 5:'Chennai'}
d1
# Out:
# {1: 'Pune', 2: 'Mumbai', 3: 'Delhi', 4: 'Bangalore', 5: 'Chennai'}

# %%
d1.items() # To fetch the items (key -- value pairs in the dictionary)
# Out:
# dict_items([(1, 'Pune'), (2, 'Mumbai'), (3, 'Delhi'), (4, 'Bangalore'), (5, 'Chennai')])

# %%
# Keys of dictionary
d1.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
# Values of dictionary
d1.values()
# Out:
# dict_values(['Pune', 'Mumbai', 'Delhi', 'Bangalore', 'Chennai'])

# %%
# To get particular value
d1.get(1)
# Out:
# 'Pune'

# %%
#Remove the key value of dictionary
# dict.pop(key)
d1.pop(3)
# Out:
# 'Delhi'

# %%
d1.pop(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 d1.pop(3)
#
# KeyError: 3

# %%
d1
# Out:
# {1: 'Pune', 2: 'Mumbai', 4: 'Bangalore', 5: 'Chennai'}

# %%
# Adding elemnts in dict
d1.update({3:'Hyderabad'})

# %%
d1
# Out:
# {1: 'Pune', 2: 'Mumbai', 4: 'Bangalore', 5: 'Chennai', 3: 'Hyderabad'}

# %%
# Copy dictionary in other dictionary
d2 = d1.copy()

# %%
d2
# Out:
# {1: 'Pune', 2: 'Mumbai', 4: 'Bangalore', 5: 'Chennai', 3: 'Hyderabad'}
