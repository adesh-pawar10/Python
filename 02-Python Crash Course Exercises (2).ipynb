# %% [markdown]
# # Python Crash Course Exercises

# %% [markdown]
# ## Exercises
#
# Answer the questions or complete the tasks outlined in bold below, use the specific method described if applicable.

# %% [markdown]
# ** What is 7 to the power of 4?**

# %%
import math

# %%
# method 1:-
p1 = math.pow(7,4)
print(p1)
print('-'*100)
# method 2:-
p2 = 7**4
print(p2)
# Out:
# 2401.0
# ----------------------------------------------------------------------------------------------------
# 2401

# %% [markdown]
# ** Split this string:**
#
#     s = "Hi there Sam!"
#
# **into a list. **

# %%
# string to list

s = "Hi there Sam!"

str_to_list = s.split()
str_to_list
# Out:
# ['Hi', 'there', 'Sam!']

# %%
# string to list

s1 = "Hi all datamitians"

str1 = s1.split()
str1
# Out:
# ['Hi', 'all', 'datamitians']

# %% [markdown]
# ** Given the variables:**
#
#     planet = "Earth"
#     diameter = 12742
#
# ** Use .format() to print the following string: **
#
#     The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# method 1 :-
# first save required format 
# then print
req_format = 'The diameter of ' + planet + ' is ' + str(diameter) + ' kilometers.'
req_format
# Out:
# 'The diameter of Earth is 12742 kilometers.'

# %%
planet = "Earth"
diameter = 12742

# method 2 :-
# using format method
print('The diameter of {} is {} kilometers.' .format(planet,diameter))
# Out:
# The diameter of Earth is 12742 kilometers.

# %% [markdown]
# ** Given this nested list, use indexing to grab the word "hello" **

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %%
# step 1 :-
lst[3]
# Out:
# [5, [100, 200, ['hello']], 23, 11]

# %%
# step 2 :-
lst[3][1]
# Out:
# [100, 200, ['hello']]

# %%
# step 3 :-
lst[3][1][2]
# Out:
# ['hello']

# %%
# final step
lst[3][1][2][0]
# Out:
# 'hello'

# %% [markdown]
# ** Given this nested dictionary grab the word "hello". Be prepared, this will be annoying/tricky **

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d
# Out:
# {'k1': [1,
#   2,
#   3,
#   {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}]}

# %%
d1 = d['k1'][3]
d1
# Out:
# {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}

# %%
d2 = d1['tricky'][3]
d2
# Out:
# {'target': [1, 2, 3, 'hello']}

# %%
req_val = d2['target'][3]
req_val
# Out:
# 'hello'

# %% [markdown]
# ** What is the main difference between a tuple and a list? **

# %%
# Tuple is immutable
# List is mutable
# Tuples requires less memory

# %% [markdown]
# ** Create a function that grabs the email website domain from a string in the form: **
#
#     user@domain.com
#
# **So for example, passing "user@domain.com" would return: domain.com**

# %%
s1 = 'user@domain.com'
s2 = s1.split('@')
s2
# Out:
# ['user', 'domain.com']

# %%
s2[-1]
# Out:
# 'domain.com'

# %%
# function to get the required format domain.com 
def domainGet(email):
    return email.split('@')[-1]

# %%
domainGet('user@domain.com')
# Out:
# 'domain.com'

# %% [markdown]
# ** Create a basic function that returns True if the word 'dog' is contained in the input string. Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization. **

# %%
str1 = 'Is there a dog here?'
str_1 = str1.lower().split()
str_1
# Out:
# ['is', 'there', 'a', 'dog', 'here?']

# %%
def findDog(str2):
    # to generalise string
    # str2 = input('Enter the required string:')
    str2 = str2.lower().split()
    if 'dog' in str2:
        print('True')
    else:
        print('False')

# %%
findDog('Is there a dog here?')
# Out:
# True

# %% [markdown]
# ** Create a function that counts the number of times the word "dog" occurs in a string. Again ignore edge cases. **

# %%
def countDog(str2):
    count = 0
    str_2 = str2.lower().split()
#     print(str_2)
    for word in str_2:
        if word == 'dog':
            count += 1
    return count

# %%
countDog('This dog runs faster than the other dog dude!')
# Out:
# 2

# %% [markdown]
# ** Use lambda expressions and the filter() function to filter out words from a list that don't start with the letter 's'. For example:**
#
#     seq = ['soup','dog','salad','cat','great']
#
# **should be filtered down to:**
#
#     ['soup','salad']

# %%
seq = ['soup','dog','salad','cat','great']

# %%
# words start with s
req_list = list(filter(lambda word: word[0] == 's', seq))
req_list
# Out:
# ['soup', 'salad']

# %%
# words don't start with s
req_list_1 = list(filter(lambda word: word[0] != 's', seq))
req_list_1
# Out:
# ['dog', 'cat', 'great']

# %% [markdown]
# ### Final Problem
# **You are driving a little too fast, and a police officer stops you. Write a function
#   to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket".
#   If your speed is 60 or less, the result is "No Ticket". If speed is between 61
#   and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big    Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all
#   cases. **

# %%
def caught_speeding(speed, is_birthday):
    # pass
    if is_birthday:
        req_speed = speed - 5
    else:
        req_speed = speed
    
    if req_speed > 80:
        # print('Big Ticket')
        return 'Big Ticket'
    elif req_speed > 60:
        # print('Small Ticket')
        return 'Small Ticket'
    else:
        # print('No Ticket')
        return 'No Ticket'

# %%
caught_speeding(81,True)
# Out:
# 'Small Ticket'

# %%
caught_speeding(81,False)
# Out:
# 'Big Ticket'
