# %%
import math

# %%
math.pow(7,4)
# Out:
# 2401.0

# %%
pwr = (7**4)
pwr
# Out:
# 2401

# %%
s1 = "Hi there Sam!"
s1
# Out:
# 'Hi there Sam!'

# %%
s1.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
lst
# Out:
# [1, 2, [3, 4], [5, [100, 200, ['hello']], 23, 11], 1, 7]

# %%
lst[3][1][2][0]
# Out:
# 'hello'

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
d
# Out:
# {'k1': [1,
#   2,
#   3,
#   {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}]}

# %%
d1 = d['k1'][3]
d1
# Out:
# {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}

# %%
d2 = d1['tricky'][3]
d2
# Out:
# {'target': [1, 2, 3, 'hello']}

# %%
req_val = d2['target'][3]
req_val
# Out:
# 'hello'

# %%
s_1 = 'Is there a dog here?'
s_1
# Out:
# 'Is there a dog here?'

# %%
s_2 = s_1.lower()
s_2
# Out:
# 'is there a dog here?'

# %%
def findDog(s_2):
    if dog in s_2:
        print('True')
    else:
        print('False')
# s_2 = "Is there a dog here?"
# findDog(s_2)
